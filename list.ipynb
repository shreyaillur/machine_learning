# %% [markdown]
# # ***data types***

# %%
name="shreya"
print(type(name))
# Out:
# <class 'str'>

# %%
name2="shreya & 123"
print(type(name2))
# Out:
# <class 'str'>

# %% [markdown]
# sequence data type list tuples range

# %%
lis=['shreya','123','30.45']
type(lis)
print(lis)
# Out:
# ['shreya', '123', '30.45']

# %%
lis= ['apple', '200', 'India']
print (len(lis))
print (len(lis2))
lis3= lis+lis2
print (lis3)
print(len(lis3))
# Out:
# 3
# 6
# ['apple', '200', 'India', 'apple', '200', 'India', 'hubli', 'shreya', 'hubli']
# 9

# %%
lis2.append("hubli")

# %%
lis2
# Out:
# ['apple', '200', 'India', 'hubli', 'shreya', 'hubli']

# %%
lis2.append("shreya")
lis2
# Out:
# ['apple', '200', 'India', 'hubli', 'shreya', 'hubli', 'shreya']

# %%
lis2.clear()

# %%
lis2
# Out:
# []

# %%
lis=['kk','aa','kle','ggg']
lis[0]
# Out:
# 'kk'

# %%
lis[2]
# Out:
# 'kle'

# %%
lis[1]
# Out:
# 'aa'

# %%
lis.sort()

# %%
lis
# Out:
# ['aa', 'ggg', 'kk', 'kle']
