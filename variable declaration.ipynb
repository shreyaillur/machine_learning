# %% [markdown]
# # ***my first program***

# %%
print("hello world")
# Out:
# hello world

# %%
a=10
b=3
sum =a+b
print(sum)
# Out:
# 13

# %% [markdown]
# # ***variable declaration***

# %%
a=5
b=10
sum=a+b
print(sum)
# Out:
# 15

# %% [markdown]
# # ***multiplication***

# %%
a=3
b=20
mul=a*b
print(mul)
# Out:
# 60

# %% [markdown]
# # **division**

# %%
a=15
b=100
div=a/b
print(div)
# Out:
# 0.15

# %% [markdown]
# # ***subtraction***

# %%
a=4
b=10
sub=a-b
print(sub)
# Out:
# -6

# %% [markdown]
# # **subtractionofthreeno**
#
# ```
#
# ```

# %%
a=10
b=5
c=3
sub=a-b-c
print(sub)
# Out:
# 2

# %% [markdown]
# # ***division(quoandrem)***

# %%
a=10
b=3
quo=a//b
rem=a%b
print(quo)
print(rem)
# Out:
# 3
# 1

# %% [markdown]
# # ***squaringnumber***

# %%
a=2
square=a**2
print(square)
# Out:
# 4

# %% [markdown]
# # ***squareroot***

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# # ***cubing***

# %%
a=3
cube=a**3
print(cube)
# Out:
# 27
