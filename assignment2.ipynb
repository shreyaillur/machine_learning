# %%
temperature = float(input("Enter the temperature in Celsius: "))

if temperature > 30:
    print("It's hot outside.")
elif temperature >= 20 and temperature <= 30:
    print("The weather is pleasant.")
else:
    print("It's quite cool.")
# Out:
# Enter the temperature in Celsius: 23
# The weather is pleasant.

# %%
word1 = input("Enter the first word: ")
word2 = input("Enter the second word: ")

if word1 == word2:
    print("The words are the same.")
else:
    print("The words are different.")
# Out:
# Enter the first word: shreya
# Enter the second word: shreya
# The words are the same.

# %%
person = ("John", 30, "Engineer")

# Accessing tuple elements
name = person[0]
age = person[1]
occupation = person[2]

# Checking age and displaying a message
if age >= 18:
    print(f"{name} is {age} years old and is a {occupation}.")
else:
    print(f"{name} is {age} years old and is not yet an adult.")
# Out:
# John is 30 years old and is a Engineer.

# %%
score = int(input("Enter your score: "))
if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
elif score >= 60:
    grade = "D"
else:
    grade = "F"

print(f"Your grade is: {grade}")
# Out:
# Enter your score: 80
# Your grade is: B

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("number is even.")
else:
    print("number is odd.")
# Out:
# Enter a number: 4
# number is even.
