# %%
import numpy as np
matrix1 = np.array([[1, 2],
                    [3, 4],
                    [5, 6]])

matrix2 = np.array([[7, 8, 9],
                    [10, 11, 12]])
result = np.dot(matrix1, matrix2)

print("Matrix 1:")
print(matrix1)

print("\nMatrix 2:")
print(matrix2)

print("\n Result of matrix multiplication:")
print(result)
# Out:
# Matrix 1:
# [[1 2]
#  [3 4]
#  [5 6]]
#
# Matrix 2:
# [[ 7  8  9]
#  [10 11 12]]
#
# Result of matrix multiplication:
# [[ 27  30  33]
#  [ 61  68  75]
#  [ 95 106 117]]

# %%
def humpty_dumpty(number):
    if number % 3 == 0 and number % 5 == 0:
        return "humpty_dumpty"
    elif number % 3 == 0:
        return "humpty"
    elif number % 5 == 0:
        return "dumpty"
    else:
        return number


number = int(input("Enter a number: "))
result = humpty_dumpty(number)
print(result)
# Out:
# Enter a number: 5
# dumpty

# %%
def sum_of_multiples(limit):
    result = 0
    for num in range(limit):
        if num % 3 == 0 or num % 5 == 0:
            result += num
    return result

limit = input("Enter the limit: ")

if limit.isdigit():
    limit = int(limit)
    total = sum_of_multiples(limit)
    print(f"The sum of multiples of 3 and 5 between 0 and {limit} is: {total}")
else:
    print("Invalid input. Please enter a valid number for the limit.")
# Out:
# Enter the limit: 55
# The sum of multiples of 3 and 5 between 0 and 55 is: 698

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,5,13,25,33,46]).reshape((-1,1))
y=np.array([3,6,9,12,14,18])
plt.scatter(x,y)
plt.xlabel("iv")
plt.ylabel("dv")
plt.show()

# %%
data=pd.read_excel('/content/evl.xlsx')
data
# Out:
#    x  y
# 0  5  2
# 1  6  8
# 2  7  4
# 3  5  9

# %%
from sklearn.linear_model import LinearRegression

# %%
SLR=LinearRegression()
SLR.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=SLR.predict(x)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='red',marker='*')
print("mse:",mse)
print("intercept:", SLR.intercept_)
print("slope:", SLR.coef_)
# Out:
# mse: 0.5056719506337065
# intercept: 3.938587739718434
# slope: [0.31193881]
