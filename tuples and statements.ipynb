# %% [markdown]
# day 2 1.how to access elements in tuples 2.join tuples 3.multiply tuples

# %%
tuple1=("hubli","belagum","hubli")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
print(tuple1[-1])
tuple6=tuple1+tuple1
print(tuple6)
tuple7=tuple6*2
print(tuple7)
y=tuple7.index('hubli')
print(y)
x=tuple7.count('hubli')
print(x)
# Out:
# hubli
# belagum
# hubli
# hubli
# ('hubli', 'belagum', 'hubli', 'hubli', 'belagum', 'hubli')
# ('hubli', 'belagum', 'hubli', 'hubli', 'belagum', 'hubli', 'hubli', 'belagum', 'hubli', 'hubli', 'belagum', 'hubli')
# 0
# 8

# %%
x=("hubli","belagum","blore")
print(type(x))
# Out:
# <class 'tuple'>

# %%
y=list(x)
y[2]="mumbai"
x=tuple(y)
print(x)
# Out:
# ('hubli', 'belagum', 'mumbai')

# %% [markdown]
# sets 1.unordered 2.unchangeable 3.duplicate not allowed

# %%
set1={"red","blue","black"}
print(set1)
set1.add('orange')
print(set1)
# Out:
# {'red', 'black', 'blue'}
# {'red', 'black', 'blue', 'orange'}

# %%
set2={"ball","bat","wicket"}
set1.update(set2)
print(set1)
# Out:
# {'red', 'wicket', 'blue', 'orange', 'bat', 'black', 'ball'}

# %%
dict1={"name":"shreya",
       "age":"20",
       "gender":"female",
       "year":"2022","year":"2014"}
print(dict1)
# Out:
# {'name': 'shreya', 'age': '20', 'gender': 'female', 'year': '2014'}

# %%
print(type(dict1))
# Out:
# <class 'dict'>

# %%
dict2=dict(fruit="banana",dessert="ice")
print(dict2)
print(type(dict2))
# Out:
# {'fruit': 'banana', 'dessert': 'ice'}
# <class 'dict'>

# %%
a=input("enter the value of a")
b=input("enter the value of b")
print(a)
print(b)
# Out:
# enter the value of a1
# enter the value of b3
# 1
# 3

# %%
if a>b:
  print("the value of a is greater than b")
if a==b:
    print("both a and b are same ")
else:
    print(a<b)
# Out:
# True

# %%
if a>b:
  print("the value of a is greater than b")
if a==b:
    print("both a and b are same ")
else:
    print('value of b is greater than a')
# Out:
# value of b is greater than a

# %%
ball1_colour="green"
ball2_colour="blue"
ball3_colour="red"
ball4_colour="white"
pick_ball=input("please pick the ball")
if pick_ball==ball1_colour:
  print("green ball is picked")
elif pick_ball==ball2_colour:
  print("blue ball is picked")
elif pick_ball==ball3_colour:
  print("red ball is picked")
else:
  print("white ball is picked")
# Out:
# please pick the ball2
# white ball is picked

# %% [markdown]
# python operators

# %%
x=12
y=4
sum=x+y
diff=x-y
prod=x*y
div=x/y
fdiv=x//y
mod=x%y
power=x**y
print(sum)
print(diff)
print(prod)
print(div)
print(fdiv)
print(mod)
print(power)
# Out:
# 16
# 8
# 48
# 3.0
# 3
# 0
# 20736

# %%
age=input("enter the age")
print(type(age))
# Out:
# enter the age1
# <class 'str'>

# %%
age=int(input("enter the age"))
print(type(age))
# Out:
# enter the age3
# <class 'int'>

# %%
age=int(input("enter the age"))
print(age>18 and age<60)
# Out:
# enter the age24
# True

# %%
age=int(input("enter the age"))
print(age>18 and age<60)
print(age>18 or age<21)
# Out:
# enter the age4
# False
# True
